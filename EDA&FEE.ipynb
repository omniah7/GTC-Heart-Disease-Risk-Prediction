# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/clean_data.csv")
data.head()
# Out:
#    age  sex  trestbps  chol  fbs  thalach  exang  oldpeak  slope  ca  target  \
# 0   63    1       145   233    1      150      0      2.3      2   0       0
# 1   67    1       160   286    0      108      1      1.5      1   3       1
# 2   67    1       120   229    0      129      1      2.6      1   2       1
# 3   37    1       130   250    0      187      0      3.5      2   0       0
# 4   41    0       130   204    0      172      0      1.4      0   0       0
#
#     cp_1   cp_2   cp_3  restecg_1  restecg_2  thal_2  thal_3
# 0  False  False  False      False       True    True   False
# 1  False  False   True      False       True   False   False
# 2  False  False   True      False       True   False    True
# 3  False   True  False      False      False   False   False
# 4   True  False  False      False       True   False   False

# %% [markdown]
# DATA EXPLORATION

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        303 non-null    int64
#  1   sex        303 non-null    int64
#  2   trestbps   303 non-null    int64
#  3   chol       303 non-null    int64
#  4   fbs        303 non-null    int64
#  5   thalach    303 non-null    int64
#  6   exang      303 non-null    int64
#  7   oldpeak    303 non-null    float64
#  8   slope      303 non-null    int64
#  9   ca         303 non-null    int64
#  10  target     303 non-null    int64
#  11  cp_1       303 non-null    bool
#  12  cp_2       303 non-null    bool
#  13  cp_3       303 non-null    bool
#  14  restecg_1  303 non-null    bool
#  15  restecg_2  303 non-null    bool
#  16  thal_2     303 non-null    bool
#  17  thal_3     303 non-null    bool
# dtypes: bool(7), float64(1), int64(10)
# memory usage: 28.2 KB

# %%
data.describe()
# Out:
#               age         sex    trestbps        chol         fbs     thalach  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868  131.689769  246.693069    0.148515  149.607261
# std      9.038662    0.467299   17.599748   51.776918    0.356198   22.875003
# min     29.000000    0.000000   94.000000  126.000000    0.000000   71.000000
# 25%     48.000000    0.000000  120.000000  211.000000    0.000000  133.500000
# 50%     56.000000    1.000000  130.000000  241.000000    0.000000  153.000000
# 75%     61.000000    1.000000  140.000000  275.000000    0.000000  166.000000
# max     77.000000    1.000000  200.000000  564.000000    1.000000  202.000000
#
#             exang     oldpeak       slope          ca      target
# count  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.326733    1.039604    0.600660    0.663366    0.458746
# std      0.469794    1.161075    0.616226    0.934375    0.499120
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.800000    1.000000    0.000000    0.000000
# 75%      1.000000    1.600000    1.000000    1.000000    1.000000
# max      1.000000    6.200000    2.000000    3.000000    1.000000

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=data["target"])
plt.title("heart disease risk distribution")
plt.xlabel("target")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=data['cp_3'])
plt.title("heart disease count for cp_3")
plt.xlabel("cp_3")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=data['thal_3'])
plt.title("heart disease count for thalassemia")
plt.xlabel("thalassemia")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=data['ca'])
plt.title("heart disease count for ca")
plt.xlabel("ca")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=data['slope'])
plt.title("heart disease count for slopes")
plt.xlabel("slope")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=data['exang'])
plt.title("heart disease count for exang")
plt.xlabel("exang")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=data["target"],y=data['oldpeak'])
plt.title("heart disease vs oldpeak")
plt.xlabel("target")
plt.ylabel("oldpeak")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=data["target"],y=data['thalach'])
plt.title("heart disease vs thalach")
plt.xlabel("target")
plt.ylabel("thalach")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=data["target"],y=data['cp_1'])
plt.title("heart disease vs cp1")
plt.xlabel("target")
plt.ylabel("cp_1")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=data["target"],y=data['cp_2'])
plt.title("heart disease vs cp_2")
plt.xlabel("target")
plt.ylabel("cp_2")
plt.show()

# %% [markdown]
# FEATURE ENGINEERING

# %%
# Age × Resting Blood Pressure
data["Age_BP_Interaction"] = data["age"] * data["trestbps"]
# Age × Cholesterol
data["Age_Chol_Interaction"] = data["age"] * data["chol"]

# Cholesterol × Resting Blood Pressure
data["Chol_BP_Interaction"] = data["chol"] * data["trestbps"]
data["BP_Chol_Ratio"] = data["trestbps"] / data["chol"]

# %%
data["Age_Squared"] = data["age"] ** 2
data["Chol_Squared"] = data["chol"] ** 2

data.to_csv("engineered_data.csv", index=False)

data.head()
# Out:
#    age  sex  trestbps  chol  fbs  thalach  exang  oldpeak  slope  ca  ...  \
# 0   63    1       145   233    1      150      0      2.3      2   0  ...
# 1   67    1       160   286    0      108      1      1.5      1   3  ...
# 2   67    1       120   229    0      129      1      2.6      1   2  ...
# 3   37    1       130   250    0      187      0      3.5      2   0  ...
# 4   41    0       130   204    0      172      0      1.4      0   0  ...
#
#    restecg_1  restecg_2  thal_2  thal_3  Age_BP_Interaction  \
# 0      False       True    True   False                9135
# 1      False       True   False   False               10720
# 2      False       True   False    True                8040
# 3      False      False   False   False                4810
# 4      False       True   False   False                5330
#
#    Age_Chol_Interaction  Chol_BP_Interaction  BP_Chol_Ratio  Age_Squared  \
# 0                 14679                33785       0.622318         3969
# 1                 19162                45760       0.559441         4489
# 2                 15343                27480       0.524017         4489
# 3                  9250                32500       0.520000         1369
# 4                  8364                26520       0.637255         1681
#
#    Chol_Squared
# 0         54289
# 1         81796
# 2         52441
# 3         62500
# 4         41616
#
# [5 rows x 24 columns]

# %%
from google.colab import files
files.download("engineered_data.csv")
